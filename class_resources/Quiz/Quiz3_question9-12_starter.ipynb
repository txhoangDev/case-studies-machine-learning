# %% [markdown]
# ## Heart Disease Predictionâ€” Multiclass Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, accuracy_score
import sys
import random
import tensorflow as tf

#import keras # Imported only for printing version info
#print(f'keras version: {keras.__version__}')
print(f'python version: {sys.version}')
print(f'numpy version: {np.__version__}')
print(f'pandas version: {pd.__version__}')
print(f'tensorflow version: {tf.__version__}')

# To get more consistent results, try to set the random seed:
random.seed(19)
np.random.seed(19)
tf.random.set_seed(19)
# Out:
# keras version: 3.10.0
# python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# numpy version: 2.0.2
# pandas version: 2.2.2
# tensorflow version: 2.19.0

# %%
# import the heart disease dataset
dataset = "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"

column_names =  ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','class']

# read the csv
dataset = pd.read_csv(dataset, names=column_names)

# remove missing data with "?"
df = dataset[~dataset.isin(['?'])]

#drop rows with NaN values from DataFrame
df = df.dropna(axis=0)

# checking data type of the dataframe
print (df.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
# transform data to numeric because ca and thal are object datatypes
data = df.apply(pd.to_numeric)
print(data.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# class         int64
# dtype: object

# %%
# plot histograms for each variable
data.hist(figsize = (15, 15))
plt.show()

# %%
# create X and Y datasets for training
X = data.iloc[:,0:13]
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,shuffle = False, random_state=90)

# There are 4 classes so we need to one-hot encode them
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# create model
model = Sequential()
model.add(Input(shape=(13,)))
model.add(Dense(10, kernel_initializer='normal', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
model.add(Dense(5, activation='softmax'))

filepath="CNN_Model-{epoch:02d}-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
train_model = model.fit(X_train, y_train, epochs=60, batch_size=8, verbose = 1, validation_data=(X_test,y_test),callbacks=[callbacks_list])
# Out:
# Epoch 1/60
# 29/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.5564 - loss: 1.5622
# Epoch 1: val_accuracy improved from -inf to 0.48333, saving model to CNN_Model-01-0.48.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 2s 13ms/step - accuracy: 0.5562 - loss: 1.5588 - val_accuracy: 0.4833 - val_loss: 1.4544
# Epoch 2/60
# 22/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.5559 - loss: 1.3184
# Epoch 2: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 9ms/step - accuracy: 0.5562 - loss: 1.3166 - val_accuracy: 0.4833 - val_loss: 1.4288
# Epoch 3/60
# 19/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 6ms/step - accuracy: 0.5591 - loss: 1.2259
# Epoch 3: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 1s 16ms/step - accuracy: 0.5562 - loss: 1.2425 - val_accuracy: 0.4833 - val_loss: 1.3899
# Epoch 4/60
# 29/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 16ms/step - accuracy: 0.5564 - loss: 1.2225
# Epoch 4: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 1s 25ms/step - accuracy: 0.5562 - loss: 1.2244 - val_accuracy: 0.4833 - val_loss: 1.3761
# Epoch 5/60
# 20/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 3ms/step - accuracy: 0.5577 - loss: 1.1983
# Epoch 5: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 7ms/step - accuracy: 0.5562 - loss: 1.2078 - val_accuracy: 0.4833 - val_loss: 1.3666
# Epoch 6/60
# 18/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 3ms/step - accuracy: 0.5605 - loss: 1.1768
# Epoch 6: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 7ms/step - accuracy: 0.5562 - loss: 1.1904 - val_accuracy: 0.4833 - val_loss: 1.3588
# Epoch 7/60
# 16/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 3ms/step - accuracy: 0.5655 - loss: 1.1511
# Epoch 7: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 8ms/step - accuracy: 0.5562 - loss: 1.1714 - val_accuracy: 0.4833 - val_loss: 1.3507
# Epoch 8/60
# 18/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 3ms/step - accuracy: 0.5605 - loss: 1.1414
# Epoch 8: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 6ms/step - accuracy: 0.5562 - loss: 1.1515 - val_accuracy: 0.4833 - val_loss: 1.3393
# Epoch 9/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.8242
# Epoch 9: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.1320 - val_accuracy: 0.4833 - val_loss: 1.3317
# Epoch 10/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.8089
# Epoch 10: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.1145 - val_accuracy: 0.4833 - val_loss: 1.3277
# Epoch 11/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.7921
# Epoch 11: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.5562 - loss: 1.1002 - val_accuracy: 0.4833 - val_loss: 1.3164
# Epoch 12/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.7826
# Epoch 12: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.0879 - val_accuracy: 0.4833 - val_loss: 1.3050
# Epoch 13/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.7737
# Epoch 13: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.0770 - val_accuracy: 0.4833 - val_loss: 1.2950
# Epoch 14/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.7632
# Epoch 14: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.0670 - val_accuracy: 0.4833 - val_loss: 1.2869
# Epoch 15/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.7509
# Epoch 15: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.0567 - val_accuracy: 0.4833 - val_loss: 1.2729
# Epoch 16/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.7428
# Epoch 16: val_accuracy did not improve from 0.48333
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5562 - loss: 1.0478 - val_accuracy: 0.4833 - val_loss: 1.2647
# Epoch 17/60
# 29/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.5564 - loss: 1.0377
# Epoch 17: val_accuracy improved from 0.48333 to 0.50000, saving model to CNN_Model-17-0.50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.5562 - loss: 1.0386 - val_accuracy: 0.5000 - val_loss: 1.2543
# Epoch 18/60
# 29/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.5784 - loss: 1.0291
# Epoch 18: val_accuracy did not improve from 0.50000
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.5784 - loss: 1.0300 - val_accuracy: 0.4833 - val_loss: 1.2410
# Epoch 19/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 23ms/step - accuracy: 0.7500 - loss: 0.7111
# Epoch 19: val_accuracy did not improve from 0.50000
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5758 - loss: 1.0220 - val_accuracy: 0.5000 - val_loss: 1.2271
# Epoch 20/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 26ms/step - accuracy: 0.7500 - loss: 0.7051
# Epoch 20: val_accuracy did not improve from 0.50000
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5758 - loss: 1.0143 - val_accuracy: 0.5000 - val_loss: 1.2174
# Epoch 21/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6962
# Epoch 21: val_accuracy did not improve from 0.50000
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5688 - loss: 1.0066 - val_accuracy: 0.5000 - val_loss: 1.2080
# Epoch 22/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6886
# Epoch 22: val_accuracy improved from 0.50000 to 0.51667, saving model to CNN_Model-22-0.52.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.5716 - loss: 0.9996 - val_accuracy: 0.5167 - val_loss: 1.1996
# Epoch 23/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 23ms/step - accuracy: 0.7500 - loss: 0.6818
# Epoch 23: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.5987 - loss: 0.9926 - val_accuracy: 0.5000 - val_loss: 1.1911
# Epoch 24/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.6777
# Epoch 24: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6126 - loss: 0.9862 - val_accuracy: 0.5000 - val_loss: 1.1849
# Epoch 25/60
# 23/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6080 - loss: 0.9819
# Epoch 25: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.6101 - loss: 0.9799 - val_accuracy: 0.5000 - val_loss: 1.1805
# Epoch 26/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 27ms/step - accuracy: 0.7500 - loss: 0.6596
# Epoch 26: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6142 - loss: 0.9738 - val_accuracy: 0.5167 - val_loss: 1.1745
# Epoch 27/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6549
# Epoch 27: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6142 - loss: 0.9687 - val_accuracy: 0.5167 - val_loss: 1.1701
# Epoch 28/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.6467
# Epoch 28: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6168 - loss: 0.9635 - val_accuracy: 0.5167 - val_loss: 1.1653
# Epoch 29/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6404
# Epoch 29: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6119 - loss: 0.9586 - val_accuracy: 0.5167 - val_loss: 1.1602
# Epoch 30/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.7500 - loss: 0.6352
# Epoch 30: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6119 - loss: 0.9536 - val_accuracy: 0.5167 - val_loss: 1.1557
# Epoch 31/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6299
# Epoch 31: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6163 - loss: 0.9487 - val_accuracy: 0.5167 - val_loss: 1.1513
# Epoch 32/60
# 21/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 3ms/step - accuracy: 0.6195 - loss: 0.9438
# Epoch 32: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.6234 - loss: 0.9437 - val_accuracy: 0.5167 - val_loss: 1.1483
# Epoch 33/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6171
# Epoch 33: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6234 - loss: 0.9390 - val_accuracy: 0.5167 - val_loss: 1.1448
# Epoch 34/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.7500 - loss: 0.6103
# Epoch 34: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6234 - loss: 0.9344 - val_accuracy: 0.5167 - val_loss: 1.1412
# Epoch 35/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 23ms/step - accuracy: 0.8750 - loss: 0.6054
# Epoch 35: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6396 - loss: 0.9301 - val_accuracy: 0.5167 - val_loss: 1.1351
# Epoch 36/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 25ms/step - accuracy: 0.8750 - loss: 0.6065
# Epoch 36: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6396 - loss: 0.9268 - val_accuracy: 0.5167 - val_loss: 1.1321
# Epoch 37/60
# 26/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6401 - loss: 0.9222
# Epoch 37: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6396 - loss: 0.9235 - val_accuracy: 0.5167 - val_loss: 1.1332
# Epoch 38/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 28ms/step - accuracy: 0.8750 - loss: 0.5876
# Epoch 38: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6396 - loss: 0.9191 - val_accuracy: 0.5167 - val_loss: 1.1287
# Epoch 39/60
# 24/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6406 - loss: 0.9157
# Epoch 39: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.6396 - loss: 0.9165 - val_accuracy: 0.4833 - val_loss: 1.1241
# Epoch 40/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 23ms/step - accuracy: 1.0000 - loss: 0.5878
# Epoch 40: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6559 - loss: 0.9139 - val_accuracy: 0.5000 - val_loss: 1.1275
# Epoch 41/60
# 28/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6528 - loss: 0.9079
# Epoch 41: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6510 - loss: 0.9099 - val_accuracy: 0.5000 - val_loss: 1.1228
# Epoch 42/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 27ms/step - accuracy: 0.8750 - loss: 0.5739
# Epoch 42: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6385 - loss: 0.9080 - val_accuracy: 0.5000 - val_loss: 1.1223
# Epoch 43/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5674
# Epoch 43: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6348 - loss: 0.9057 - val_accuracy: 0.5000 - val_loss: 1.1203
# Epoch 44/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5638
# Epoch 44: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6348 - loss: 0.9025 - val_accuracy: 0.4833 - val_loss: 1.1214
# Epoch 45/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5559
# Epoch 45: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6348 - loss: 0.9007 - val_accuracy: 0.4833 - val_loss: 1.1205
# Epoch 46/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 1s 43ms/step - accuracy: 0.8750 - loss: 0.5516
# Epoch 46: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6348 - loss: 0.8981 - val_accuracy: 0.5000 - val_loss: 1.1192
# Epoch 47/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5481
# Epoch 47: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6351 - loss: 0.8952 - val_accuracy: 0.4833 - val_loss: 1.1205
# Epoch 48/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 27ms/step - accuracy: 0.8750 - loss: 0.5418
# Epoch 48: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6351 - loss: 0.8927 - val_accuracy: 0.4833 - val_loss: 1.1191
# Epoch 49/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 23ms/step - accuracy: 0.8750 - loss: 0.5391
# Epoch 49: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6429 - loss: 0.8907 - val_accuracy: 0.4833 - val_loss: 1.1203
# Epoch 50/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5344
# Epoch 50: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6426 - loss: 0.8885 - val_accuracy: 0.4833 - val_loss: 1.1213
# Epoch 51/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5307
# Epoch 51: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6426 - loss: 0.8880 - val_accuracy: 0.5000 - val_loss: 1.1257
# Epoch 52/60
# 29/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6433 - loss: 0.8826
# Epoch 52: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.6426 - loss: 0.8844 - val_accuracy: 0.5000 - val_loss: 1.1272
# Epoch 53/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 29ms/step - accuracy: 0.8750 - loss: 0.5222
# Epoch 53: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6446 - loss: 0.8833 - val_accuracy: 0.5000 - val_loss: 1.1321
# Epoch 54/60
# 25/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 2ms/step - accuracy: 0.6456 - loss: 0.8768
# Epoch 54: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6446 - loss: 0.8805 - val_accuracy: 0.5000 - val_loss: 1.1320
# Epoch 55/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5143
# Epoch 55: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6367 - loss: 0.8805 - val_accuracy: 0.5000 - val_loss: 1.1436
# Epoch 56/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 28ms/step - accuracy: 0.8750 - loss: 0.5041
# Epoch 56: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6399 - loss: 0.8778 - val_accuracy: 0.5000 - val_loss: 1.1466
# Epoch 57/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 27ms/step - accuracy: 0.8750 - loss: 0.4999
# Epoch 57: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6328 - loss: 0.8765 - val_accuracy: 0.5167 - val_loss: 1.1472
# Epoch 58/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 28ms/step - accuracy: 0.8750 - loss: 0.5013
# Epoch 58: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6590 - loss: 0.8728 - val_accuracy: 0.5000 - val_loss: 1.1433
# Epoch 59/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 24ms/step - accuracy: 0.8750 - loss: 0.5022
# Epoch 59: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 5ms/step - accuracy: 0.6477 - loss: 0.8731 - val_accuracy: 0.5167 - val_loss: 1.1445
# Epoch 60/60
#  1/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 27ms/step - accuracy: 0.8750 - loss: 0.5017
# Epoch 60: val_accuracy did not improve from 0.51667
# 30/30 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 4ms/step - accuracy: 0.6511 - loss: 0.8701 - val_accuracy: 0.5000 - val_loss: 1.1416

# %%
# Plotting the model
plt.plot(train_model.history['accuracy'], marker='.')
plt.plot(train_model.history['val_accuracy'], marker='.')
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
plt.savefig('model_accuracy.png')
plt.close()

plt.plot(train_model.history['loss'], marker='.')
plt.plot(train_model.history['val_loss'], marker='.')
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.savefig('model_loss.png')
plt.close()

# %%
pred = model.predict(X_test)

print('Maximum Probabilities of Test Dataset: ',np.max(pred, axis=-1))
# Out:
# 2/2 â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 0s 57ms/step
# Maximum Probabilities of Test Dataset:  [0.93154275 0.9584911  0.9412404  0.64182097 0.7652624  0.33871827
#  0.61423653 0.23947188 0.40635583 0.8967156  0.24394438 0.2831606
#  0.2828778  0.90669525 0.9207028  0.96138024 0.7589875  0.7665884
#  0.89488596 0.73817325 0.8582793  0.8252998  0.97382116 0.9472551
#  0.2831606  0.25466612 0.283543   0.85453725 0.90855706 0.2831606
#  0.28845727 0.2831606  0.7933849  0.882291   0.76683563 0.85280454
#  0.92245597 0.8929442  0.8344717  0.27661058 0.9602227  0.2831606
#  0.9613767  0.6698593  0.2831606  0.2831606  0.8214171  0.95382327
#  0.5859586  0.95242155 0.24788699 0.2831606  0.83633506 0.9726821
#  0.2831606  0.29996705 0.5697544  0.28316057 0.28316057 0.93697417]

# %%
for i in pred:
    if(np.max(i) > 0.8):
        print("Critical")
    elif(np.max(i) > 0.5):
        print("moderate or severe")
    elif(np.max(i) > 0.3):
        print("mild or moderate")
    else:
        print("None")
# Out:
# Critical
# Critical
# Critical
# moderate or severe
# moderate or severe
# mild or moderate
# moderate or severe
# None
# mild or moderate
# Critical
# None
# None
# None
# Critical
# Critical
# Critical
# moderate or severe
# moderate or severe
# Critical
# moderate or severe
# Critical
# Critical
# Critical
# Critical
# None
# None
# None
# Critical
# Critical
# None
# None
# None
# moderate or severe
# Critical
# moderate or severe
# Critical
# Critical
# Critical
# Critical
# None
# Critical
# None
# Critical
# moderate or severe
# None
# None
# Critical
# Critical
# moderate or severe
# Critical
# None
# None
# Critical
# Critical
# None
# None
# moderate or severe
# None
# None
# Critical

# %%
# need to take argmax if it is a multiclass problem
y_pred_argmax = np.argmax(pred, axis=1)
y_test_argmax = np.argmax(y_test, axis=1)

print('Classification Accuracy: '+str(accuracy_score(y_test_argmax, y_pred_argmax) * 100)+' %')
# Out:
# Classification Accuracy: 50.0 %
